# %%
# traffic light
light = input ( " light color :")
if( light == " red"):
  print("stop")
  elif( light == "yellow"):
    print("look")
    elif( light == "green"):
      print("go")
      else
      print(" light is broken")
# Out:
#   File "/tmp/ipykernel_1678/640835852.py", line 5
#     elif( light == "yellow"):
#     ^
# SyntaxError: invalid syntax

# %%
#traffic light
light = input ( " light color :")
if( light == " red"):
  print("stop")
elif( light == "yellow"):
  print("look")
elif( light == "green"):
  print("go")
else:
  print(" light is broken")
# Out:
#  light color :green
# go

# %%
light = input ("light color :" )
if( light == "red"):
    print( "stop")
elif( light == "yellow"):
    print( "look")
elif(light == "green"):
    print("go")
else:
    print("light is broken")
# Out:
# light color :red
# stop

# %%
light = input("light color :")
if(light == "red"):
    print("stop")
elif(ligt == "yellow"):
    print("look")
    elif(light == "green"):
        print("go")
  else:
    print("light is broken")

# %%
light = input( " light color:")
if(light == "red")
   print("stop")
elif(light == "yellow"):
    print("look")
elif(light == "green"):
  print("go")
else:
  print("light is broken")

# %%
light = input("light color")
if ( light == "red")
    print("stop")
    elif(  light == "yellow")
        print("look")
  elif(light == "green"):
    print("go")
else
